# %% [markdown]
# #Fun with IPC XML, Python xml, lxml and ElementTree
#
# ###Python Quellen
# * John Shipman's tutorial on [Python XML processing with lxml](https://www.academia.edu/38587906/Python_XML_processing_with_lxml)
# * [The ElementTree API on](https://docs.python.org/3/library/xml.etree.elementtree.html) on python.org
# * Tutorials on [Real Python](https://realpython.com/)
# * [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
#
# ###WIPO Links
# * Current Edition of IPC Master Files from [WIPO's Download and IT support area](https://www.wipo.int/classifications/ipc/en/ITsupport/), here the  [direkt link zu the zip File](https://www.wipo.int/ipc/itos4ipc/ITSupport_and_download_area//20210101/MasterFiles/ipc_scheme_images_20210101.zip)
# * Documentation and XSDs are [here](https://www.wipo.int/classifications/ipc/en/ITsupport/Version20210101/documentation/IPCfiles.html), esp. the Specification of the Scheme file [here](https://www.wipo.int/ipc/itos4ipc/ITSupport_and_download_area/Documentation/20210101/IPC_scheme_specs_v3_1.docx)
# * [Link](https://www.wipo.int/classifications/ipc/ipcpub/?notion=scheme&version=20210101&symbol=none&menulang=en&lang=en&viewmode=f&fipcpc=no&showdeleted=yes&indexes=no&headings=yes&notes=yes&direction=o2n&initial=A&cwid=none&tree=no&searchmode=smart) to the IPC Browser of WIPO
#
#
# First, we download the IPC XML from WIPO, to work with it further down the road. This is every time needed, after this machine here restarted!

# %%
import requests, zipfile, io, os, time

tic = time.perf_counter() * 1000

url = 'https://www.wipo.int/ipc/itos4ipc/ITSupport_and_download_area//20210101/MasterFiles/ipc_scheme_20210101.zip'
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

filename = os.listdir()[1]

toc = time.perf_counter() * 1000

print('downloaded and unzipped', filename, f'in: {(toc - tic):0.0f} ms')
# Out:
# downloaded and unzipped patstat_training in: 440 ms

# %% [markdown]
# #First Sample Code

# %% [markdown]
# First, we just import lxml and get the file (manual download, put it here next to the sample data) and access it, print the upper level elements tags and the attribut dictonary. These are the sections of the IPC Tree. The attributes contain: 'kind' and 'symbol' and 'entryTpe'.

# %%
from lxml import etree as ET

filename = "./EN_ipc_scheme_20210101.xml"
parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

for child in root:
    print(child.tag, child.attrib)
# Out:
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'A', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'B', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'C', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'D', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'E', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'F', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'G', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'H', 'entryType': 'K'}

# %% [markdown]
# just a different, shorter way of doing this stuff

# %%
import xml.etree.ElementTree as ET
root = ET.parse("./EN_ipc_scheme_20210101.xml").getroot()

for sections in root:
   print(sections.tag, sections.attrib)
# Out:
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'A', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'B', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'C', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'D', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'E', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'F', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'G', 'entryType': 'K'}
# {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry {'kind': 's', 'symbol': 'H', 'entryType': 'K'}

# %% [markdown]
# #What do we see?
#
# The **tag** (including the xmlns - NameSpace, that this entry belongs. There is only one ns in the XML btw.) and the **attributes**, obviously, and the **atributes** you can see in the next text box.

# %% [markdown]
# ##Atributes
# ###'kind' with its Values:
# * s = section
# * t = sub-section title
# * c = class
# * i = sub-class index
# * u = sub-class
# * g = guidance heading
#   m = main group
# * 1 to B = 11 levels of group (hexadecimal notation)
# * n = note
#
# ###'symbol' with its Values:
#
# ###The IPC Symbol! Thats the thing...
#
# ###'entryType' with its Values:
# * K = classification symbol (default, i.e. for classification purpose only)
# * I = Indexing symbol  (i.e. for indexing purpose only)
# * D = Double purpose classification symbol (i.e. for both classification and indexing purpose) – existed only prior to the IPC reform
# * Z = problematic entry (i.e. structure and/or contents have been partially converted from CPC or FI)
# Interesting for us, are only entryType 'K'

# %% [markdown]
# ##Dictionaries for kind level and title of level
# ```
# kind_to_level = {
#   's':1,
#   'c':2,
#   'u':3,
#   'g':4,
#   'm':4,
#   '1':5,
#   '2':6,
#   '3':7,
#   '4':8,
#   '5':9,
#   '6':10,
#   '7':11,
#   '8':12,
#   '9':13,
#   'A':14,
#   'B':15}
#
# kind_to_levelTitle = {
#   's':'section',
#   't':'sub-section title',
#   'c':'class',
#   'I':'sub-class index',
#   'u':'sub-class',
#   'g':'guidance heading',
#   'm':'main group',
#   '1':'.subgroup',
#   '2':'..subgroup',
#   '3':'...subgroup',
#   '4':'....subgroup',
#   '5':'.....subgroup',
#   '6':'......subgroup',
#   '7':'.......subgroup',
#   '8':'........subgroup',
#   '9':'.........subgroup',
#   'A':'..........subgroup',
#   'B':'...........subgroup',
#   'n':'note'}
# ```

# %% [markdown]
# ##here the list for all the interesing entries in our IPC XML
#
# ```
# whatlevel = ["s","c","u","m","1","2","3","4","5","6","7","8","9","A","B"]
# ```

# %% [markdown]
# #Next Sample Code
#
# Now we use lxml again and try to iterate two levels down and print a list of section, classes and sub classes.

# %%
from lxml import etree as ET

filename = "./EN_ipc_scheme_20210101.xml"
parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

ipcEntry = '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'

for sections in root:
    print('1st level sections: ', sections.attrib['symbol'], " kind:", sections.attrib['kind'])

    #go one level deeper to classes
    for classes in sections.iterchildren(tag=ipcEntry):
      print('2nd level classes: ', classes.attrib['symbol'], " kind:", classes.attrib['kind'])

      #go one level deeper to sub classes
      for subclasses in classes.iterchildren(tag=ipcEntry):
        print('3nd level sub classes: ', subclasses.attrib['symbol'], " kind:", subclasses.attrib['kind'])
# Out:
# 1st level sections:  A  kind: s
# 2nd level classes:  A01  kind: t
# 2nd level classes:  A01  kind: c
# 3nd level sub classes:  A01B  kind: u
# 3nd level sub classes:  A01C  kind: u
# 3nd level sub classes:  A01D  kind: u
# 3nd level sub classes:  A01F  kind: u
# 3nd level sub classes:  A01G  kind: u
# 3nd level sub classes:  A01H  kind: u
# 3nd level sub classes:  A01J  kind: u
# 3nd level sub classes:  A01K  kind: u
# 3nd level sub classes:  A01L  kind: u
# 3nd level sub classes:  A01M  kind: u
# 3nd level sub classes:  A01N  kind: u
# 3nd level sub classes:  A01P  kind: u
# 2nd level classes:  A21  kind: t
# 2nd level classes:  A21  kind: c
# 3nd level sub classes:  A21B  kind: u
# 3nd level sub classes:  A21C  kind: u
# 3nd level sub classes:  A21D  kind: u
# 2nd level classes:  A22  kind: c
# 3nd level sub classes:  A22B  kind: u
# 3nd level sub classes:  A22C  kind: u
# 2nd level classes:  A23  kind: c
# 3nd level sub classes:  A23  kind: n
# 3nd level sub classes:  A23B  kind: u
# 3nd level sub classes:  A23C  kind: u
# 3nd level sub classes:  A23D  kind: u
# 3nd level sub classes:  A23F  kind: u
# 3nd level sub classes:  A23G  kind: u
# 3nd level sub classes:  A23J  kind: u
# 3nd level sub classes:  A23K  kind: u
# 3nd level sub classes:  A23L  kind: u
# 3nd level sub classes:  A23N  kind: u
# 3nd level sub classes:  A23P  kind: u
# 2nd level classes:  A24  kind: c
# 3nd level sub classes:  A24  kind: n
# 3nd level sub classes:  A24B  kind: u
# 3nd level sub classes:  A24C  kind: u
# 3nd level sub classes:  A24D  kind: u
# 3nd level sub classes:  A24F  kind: u
# 2nd level classes:  A41  kind: t
# 2nd level classes:  A41  kind: c
# 3nd level sub classes:  A41B  kind: u
# 3nd level sub classes:  A41C  kind: u
# 3nd level sub classes:  A41D  kind: u
# 3nd level sub classes:  A41F  kind: u
# 3nd level sub classes:  A41G  kind: u
# 3nd level sub classes:  A41H  kind: u
# 2nd level classes:  A42  kind: c
# 3nd level sub classes:  A42B  kind: u
# 3nd level sub classes:  A42C  kind: u
# 2nd level classes:  A43  kind: c
# 3nd level sub classes:  A43B  kind: u
# 3nd level sub classes:  A43C  kind: u
# 3nd level sub classes:  A43D  kind: u
# 2nd level classes:  A44  kind: c
# 3nd level sub classes:  A44B  kind: u
# 3nd level sub classes:  A44C  kind: u
# 2nd level classes:  A45  kind: c
# 3nd level sub classes:  A45B  kind: u
# 3nd level sub classes:  A45C  kind: u
# 3nd level sub classes:  A45D  kind: u
# 3nd level sub classes:  A45F  kind: u
# 2nd level classes:  A46  kind: c
# 3nd level sub classes:  A46B  kind: u
# 3nd level sub classes:  A46D  kind: u
# 2nd level classes:  A47  kind: c
# 3nd level sub classes:  A47  kind: n
# 3nd level sub classes:  A47B  kind: u
# 3nd level sub classes:  A47C  kind: u
# 3nd level sub classes:  A47D  kind: u
# 3nd level sub classes:  A47F  kind: u
# 3nd level sub classes:  A47G  kind: u
# 3nd level sub classes:  A47H  kind: u
# 3nd level sub classes:  A47J  kind: u
# 3nd level sub classes:  A47K  kind: u
# 3nd level sub classes:  A47L  kind: u
# 2nd level classes:  A61  kind: t
# 2nd level classes:  A61  kind: c
# 3nd level sub classes:  A61B  kind: u
# 3nd level sub classes:  A61C  kind: u
# 3nd level sub classes:  A61D  kind: u
# 3nd level sub classes:  A61F  kind: u
# 3nd level sub classes:  A61G  kind: u
# 3nd level sub classes:  A61H  kind: u
# 3nd level sub classes:  A61J  kind: u
# 3nd level sub classes:  A61K  kind: u
# 3nd level sub classes:  A61L  kind: u
# 3nd level sub classes:  A61M  kind: u
# 3nd level sub classes:  A61N  kind: u
# 3nd level sub classes:  A61P  kind: u
# 3nd level sub classes:  A61Q  kind: u
# 2nd level classes:  A62  kind: c
# 3nd level sub classes:  A62B  kind: u
# 3nd level sub classes:  A62C  kind: u
# 3nd level sub classes:  A62D  kind: u
# 2nd level classes:  A63  kind: c
# 3nd level sub classes:  A63B  kind: u
# 3nd level sub classes:  A63C  kind: u
# 3nd level sub classes:  A63D  kind: u
# 3nd level sub classes:  A63F  kind: u
# 3nd level sub classes:  A63G  kind: u
# 3nd level sub classes:  A63H  kind: u
# 3nd level sub classes:  A63J  kind: u
# 3nd level sub classes:  A63K  kind: u
# 2nd level classes:  A99  kind: c
# 3nd level sub classes:  A99Z  kind: u
# 1st level sections:  B  kind: s
# 2nd level classes:  B01  kind: t
# 2nd level classes:  B01  kind: n
# 2nd level classes:  B01  kind: i
# 2nd level classes:  B01  kind: c
# 3nd level sub classes:  B01B  kind: u
# 3nd level sub classes:  B01D  kind: u
# 3nd level sub classes:  B01F  kind: u
# 3nd level sub classes:  B01J  kind: u
# 3nd level sub classes:  B01L  kind: u
# 2nd level classes:  B02  kind: c
# 3nd level sub classes:  B02B  kind: u
# 3nd level sub classes:  B02C  kind: u
# 2nd level classes:  B03  kind: c
# 3nd level sub classes:  B03B  kind: u
# 3nd level sub classes:  B03C  kind: u
# 3nd level sub classes:  B03D  kind: u
# 2nd level classes:  B04  kind: c
# 3nd level sub classes:  B04  kind: n
# 3nd level sub classes:  B04B  kind: u
# 3nd level sub classes:  B04C  kind: u
# 2nd level classes:  B05  kind: c
# 3nd level sub classes:  B05B  kind: u
# 3nd level sub classes:  B05C  kind: u
# 3nd level sub classes:  B05D  kind: u
# 2nd level classes:  B06  kind: c
# 3nd level sub classes:  B06B  kind: u
# 2nd level classes:  B07  kind: c
# 3nd level sub classes:  B07B  kind: u
# 3nd level sub classes:  B07C  kind: u
# 2nd level classes:  B08  kind: c
# 3nd level sub classes:  B08B  kind: u
# 2nd level classes:  B09  kind: c
# 3nd level sub classes:  B09B  kind: u
# 3nd level sub classes:  B09C  kind: u
# 2nd level classes:  B21  kind: t
# 2nd level classes:  B21  kind: c
# 3nd level sub classes:  B21  kind: n
# 3nd level sub classes:  B21B  kind: u
# 3nd level sub classes:  B21C  kind: u
# 3nd level sub classes:  B21D  kind: u
# 3nd level sub classes:  B21F  kind: u
# 3nd level sub classes:  B21G  kind: u
# 3nd level sub classes:  B21H  kind: u
# 3nd level sub classes:  B21J  kind: u
# 3nd level sub classes:  B21K  kind: u
# 3nd level sub classes:  B21L  kind: u
# 2nd level classes:  B22  kind: c
# 3nd level sub classes:  B22C  kind: u
# 3nd level sub classes:  B22D  kind: u
# 3nd level sub classes:  B22F  kind: u
# 2nd level classes:  B23  kind: c
# 3nd level sub classes:  B23  kind: n
# 3nd level sub classes:  B23B  kind: u
# 3nd level sub classes:  B23C  kind: u
# 3nd level sub classes:  B23D  kind: u
# 3nd level sub classes:  B23F  kind: u
# 3nd level sub classes:  B23G  kind: u
# 3nd level sub classes:  B23H  kind: u
# 3nd level sub classes:  B23K  kind: u
# 3nd level sub classes:  B23P  kind: u
# 3nd level sub classes:  B23Q  kind: u
# 2nd level classes:  B24  kind: c
# 3nd level sub classes:  B24  kind: n
# 3nd level sub classes:  B24B  kind: u
# 3nd level sub classes:  B24C  kind: u
# 3nd level sub classes:  B24D  kind: u
# 2nd level classes:  B25  kind: c
# 3nd level sub classes:  B25  kind: n
# 3nd level sub classes:  B25B  kind: u
# 3nd level sub classes:  B25C  kind: u
# 3nd level sub classes:  B25D  kind: u
# 3nd level sub classes:  B25F  kind: u
# 3nd level sub classes:  B25G  kind: u
# 3nd level sub classes:  B25H  kind: u
# 3nd level sub classes:  B25J  kind: u
# 2nd level classes:  B26  kind: c
# 3nd level sub classes:  B26B  kind: u
# 3nd level sub classes:  B26D  kind: u
# 3nd level sub classes:  B26F  kind: u
# 2nd level classes:  B27  kind: c
# 3nd level sub classes:  B27B  kind: u
# 3nd level sub classes:  B27C  kind: u
# 3nd level sub classes:  B27D  kind: u
# 3nd level sub classes:  B27F  kind: u
# 3nd level sub classes:  B27G  kind: u
# 3nd level sub classes:  B27H  kind: u
# 3nd level sub classes:  B27J  kind: u
# 3nd level sub classes:  B27K  kind: u
# 3nd level sub classes:  B27L  kind: u
# 3nd level sub classes:  B27M  kind: u
# 3nd level sub classes:  B27N  kind: u
# 2nd level classes:  B28  kind: c
# 3nd level sub classes:  B28B  kind: u
# 3nd level sub classes:  B28C  kind: u
# 3nd level sub classes:  B28D  kind: u
# 2nd level classes:  B29  kind: c
# 3nd level sub classes:  B29  kind: n
# 3nd level sub classes:  B29B  kind: u
# 3nd level sub classes:  B29C  kind: u
# 3nd level sub classes:  B29D  kind: u
# 3nd level sub classes:  B29K  kind: u
# 3nd level sub classes:  B29L  kind: u
# 2nd level classes:  B30  kind: c
# 3nd level sub classes:  B30B  kind: u
# 2nd level classes:  B31  kind: c
# 3nd level sub classes:  B31  kind: n
# 3nd level sub classes:  B31B  kind: u
# 3nd level sub classes:  B31C  kind: u
# 3nd level sub classes:  B31D  kind: u
# 3nd level sub classes:  B31F  kind: u
# 2nd level classes:  B32  kind: c
# 3nd level sub classes:  B32B  kind: u
# 2nd level classes:  B33  kind: c
# 3nd level sub classes:  B33Y  kind: u
# 2nd level classes:  B41  kind: t
# 2nd level classes:  B41  kind: c
# 3nd level sub classes:  B41B  kind: u
# 3nd level sub classes:  B41C  kind: u
# 3nd level sub classes:  B41D  kind: u
# 3nd level sub classes:  B41F  kind: u
# 3nd level sub classes:  B41G  kind: u
# 3nd level sub classes:  B41J  kind: u
# 3nd level sub classes:  B41K  kind: u
# 3nd level sub classes:  B41L  kind: u
# 3nd level sub classes:  B41M  kind: u
# 3nd level sub classes:  B41N  kind: u
# 2nd level classes:  B42  kind: c
# 3nd level sub classes:  B42B  kind: u
# 3nd level sub classes:  B42C  kind: u
# 3nd level sub classes:  B42D  kind: u
# 3nd level sub classes:  B42F  kind: u
# 2nd level classes:  B43  kind: c
# 3nd level sub classes:  B43K  kind: u
# 3nd level sub classes:  B43L  kind: u
# 3nd level sub classes:  B43M  kind: u
# 2nd level classes:  B44  kind: c
# 3nd level sub classes:  B44  kind: n
# 3nd level sub classes:  B44B  kind: u
# 3nd level sub classes:  B44C  kind: u
# 3nd level sub classes:  B44D  kind: u
# 3nd level sub classes:  B44F  kind: u
# 2nd level classes:  B60  kind: t
# 2nd level classes:  B60  kind: c
# 3nd level sub classes:  B60  kind: n
# 3nd level sub classes:  B60B  kind: u
# 3nd level sub classes:  B60C  kind: u
# 3nd level sub classes:  B60D  kind: u
# 3nd level sub classes:  B60F  kind: u
# 3nd level sub classes:  B60G  kind: u
# 3nd level sub classes:  B60H  kind: u
# 3nd level sub classes:  B60J  kind: u
# 3nd level sub classes:  B60K  kind: u
# 3nd level sub classes:  B60L  kind: u
# 3nd level sub classes:  B60M  kind: u
# 3nd level sub classes:  B60N  kind: u
# 3nd level sub classes:  B60P  kind: u
# 3nd level sub classes:  B60Q  kind: u
# 3nd level sub classes:  B60R  kind: u
# 3nd level sub classes:  B60S  kind: u
# 3nd level sub classes:  B60T  kind: u
# 3nd level sub classes:  B60V  kind: u
# 3nd level sub classes:  B60W  kind: u
# 2nd level classes:  B61  kind: c
# 3nd level sub classes:  B61  kind: n
# 3nd level sub classes:  B61B  kind: u
# 3nd level sub classes:  B61C  kind: u
# 3nd level sub classes:  B61D  kind: u
# 3nd level sub classes:  B61F  kind: u
# 3nd level sub classes:  B61G  kind: u
# 3nd level sub classes:  B61H  kind: u
# 3nd level sub classes:  B61J  kind: u
# 3nd level sub classes:  B61K  kind: u
# 3nd level sub classes:  B61L  kind: u
# 2nd level classes:  B62  kind: c
# 3nd level sub classes:  B62B  kind: u
# 3nd level sub classes:  B62C  kind: u
# 3nd level sub classes:  B62D  kind: u
# 3nd level sub classes:  B62H  kind: u
# 3nd level sub classes:  B62J  kind: u
# 3nd level sub classes:  B62K  kind: u
# 3nd level sub classes:  B62L  kind: u
# 3nd level sub classes:  B62M  kind: u
# 2nd level classes:  B63  kind: c
# 3nd level sub classes:  B63B  kind: u
# 3nd level sub classes:  B63C  kind: u
# 3nd level sub classes:  B63G  kind: u
# 3nd level sub classes:  B63H  kind: u
# 3nd level sub classes:  B63J  kind: u
# 2nd level classes:  B64  kind: c
# 3nd level sub classes:  B64B  kind: u
# 3nd level sub classes:  B64C  kind: u
# 3nd level sub classes:  B64D  kind: u
# 3nd level sub classes:  B64F  kind: u
# 3nd level sub classes:  B64G  kind: u
# 2nd level classes:  B65  kind: c
# 3nd level sub classes:  B65B  kind: u
# 3nd level sub classes:  B65C  kind: u
# 3nd level sub classes:  B65D  kind: u
# 3nd level sub classes:  B65F  kind: u
# 3nd level sub classes:  B65G  kind: u
# 3nd level sub classes:  B65H  kind: u
# 2nd level classes:  B66  kind: c
# 3nd level sub classes:  B66B  kind: u
# 3nd level sub classes:  B66C  kind: u
# 3nd level sub classes:  B66D  kind: u
# 3nd level sub classes:  B66F  kind: u
# 2nd level classes:  B67  kind: c
# 3nd level sub classes:  B67B  kind: u
# 3nd level sub classes:  B67C  kind: u
# 3nd level sub classes:  B67D  kind: u
# 2nd level classes:  B68  kind: c
# 3nd level sub classes:  B68B  kind: u
# 3nd level sub classes:  B68C  kind: u
# 3nd level sub classes:  B68F  kind: u
# 3nd level sub classes:  B68G  kind: u
# 2nd level classes:  B81  kind: t
# 2nd level classes:  B81  kind: c
# 3nd level sub classes:  B81  kind: n
# 3nd level sub classes:  B81B  kind: u
# 3nd level sub classes:  B81C  kind: u
# 2nd level classes:  B82  kind: c
# 3nd level sub classes:  B82  kind: n
# 3nd level sub classes:  B82B  kind: u
# 3nd level sub classes:  B82Y  kind: u
# 2nd level classes:  B99  kind: c
# 3nd level sub classes:  B99Z  kind: u
# 1st level sections:  C  kind: s
# 2nd level classes:  C  kind: n
# 2nd level classes:  C01  kind: t
# 2nd level classes:  C01  kind: c
# 3nd level sub classes:  C01  kind: n
# 3nd level sub classes:  C01B  kind: u
# 3nd level sub classes:  C01C  kind: u
# 3nd level sub classes:  C01D  kind: u
# 3nd level sub classes:  C01F  kind: u
# 3nd level sub classes:  C01G  kind: u
# 2nd level classes:  C02  kind: c
# 3nd level sub classes:  C02F  kind: u
# 2nd level classes:  C03  kind: c
# 3nd level sub classes:  C03B  kind: u
# 3nd level sub classes:  C03C  kind: u
# 2nd level classes:  C04  kind: c
# 3nd level sub classes:  C04  kind: n
# 3nd level sub classes:  C04B  kind: u
# 2nd level classes:  C05  kind: c
# 3nd level sub classes:  C05  kind: n
# 3nd level sub classes:  C05B  kind: u
# 3nd level sub classes:  C05C  kind: u
# 3nd level sub classes:  C05D  kind: u
# 3nd level sub classes:  C05F  kind: u
# 3nd level sub classes:  C05G  kind: u
# 2nd level classes:  C06  kind: c
# 3nd level sub classes:  C06B  kind: u
# 3nd level sub classes:  C06C  kind: u
# 3nd level sub classes:  C06D  kind: u
# 3nd level sub classes:  C06F  kind: u
# 2nd level classes:  C07  kind: c
# 3nd level sub classes:  C07  kind: n
# 3nd level sub classes:  C07B  kind: u
# 3nd level sub classes:  C07C  kind: u
# 3nd level sub classes:  C07D  kind: u
# 3nd level sub classes:  C07F  kind: u
# 3nd level sub classes:  C07G  kind: u
# 3nd level sub classes:  C07H  kind: u
# 3nd level sub classes:  C07J  kind: u
# 3nd level sub classes:  C07K  kind: u
# 2nd level classes:  C08  kind: c
# 3nd level sub classes:  C08  kind: n
# 3nd level sub classes:  C08B  kind: u
# 3nd level sub classes:  C08C  kind: u
# 3nd level sub classes:  C08F  kind: u
# 3nd level sub classes:  C08G  kind: u
# 3nd level sub classes:  C08H  kind: u
# 3nd level sub classes:  C08J  kind: u
# 3nd level sub classes:  C08K  kind: u
# 3nd level sub classes:  C08L  kind: u
# 2nd level classes:  C09  kind: c
# 3nd level sub classes:  C09B  kind: u
# 3nd level sub classes:  C09C  kind: u
# 3nd level sub classes:  C09D  kind: u
# 3nd level sub classes:  C09F  kind: u
# 3nd level sub classes:  C09G  kind: u
# 3nd level sub classes:  C09H  kind: u
# 3nd level sub classes:  C09J  kind: u
# 3nd level sub classes:  C09K  kind: u
# 2nd level classes:  C10  kind: c
# 3nd level sub classes:  C10B  kind: u
# 3nd level sub classes:  C10C  kind: u
# 3nd level sub classes:  C10F  kind: u
# 3nd level sub classes:  C10G  kind: u
# 3nd level sub classes:  C10H  kind: u
# 3nd level sub classes:  C10J  kind: u
# 3nd level sub classes:  C10K  kind: u
# 3nd level sub classes:  C10L  kind: u
# 3nd level sub classes:  C10M  kind: u
# 3nd level sub classes:  C10N  kind: u
# 2nd level classes:  C11  kind: c
# 3nd level sub classes:  C11B  kind: u
# 3nd level sub classes:  C11C  kind: u
# 3nd level sub classes:  C11D  kind: u
# 2nd level classes:  C12  kind: c
# 3nd level sub classes:  C12  kind: n
# 3nd level sub classes:  C12C  kind: u
# 3nd level sub classes:  C12F  kind: u
# 3nd level sub classes:  C12G  kind: u
# 3nd level sub classes:  C12H  kind: u
# 3nd level sub classes:  C12J  kind: u
# 3nd level sub classes:  C12L  kind: u
# 3nd level sub classes:  C12M  kind: u
# 3nd level sub classes:  C12N  kind: u
# 3nd level sub classes:  C12P  kind: u
# 3nd level sub classes:  C12Q  kind: u
# 3nd level sub classes:  C12R  kind: u
# 2nd level classes:  C13  kind: c
# 3nd level sub classes:  C13  kind: n
# 3nd level sub classes:  C13B  kind: u
# 3nd level sub classes:  C13K  kind: u
# 2nd level classes:  C14  kind: c
# 3nd level sub classes:  C14B  kind: u
# 3nd level sub classes:  C14C  kind: u
# 2nd level classes:  C21  kind: t
# 2nd level classes:  C21  kind: c
# 3nd level sub classes:  C21B  kind: u
# 3nd level sub classes:  C21C  kind: u
# 3nd level sub classes:  C21D  kind: u
# 2nd level classes:  C22  kind: c
# 3nd level sub classes:  C22  kind: n
# 3nd level sub classes:  C22B  kind: u
# 3nd level sub classes:  C22C  kind: u
# 3nd level sub classes:  C22F  kind: u
# 2nd level classes:  C23  kind: c
# 3nd level sub classes:  C23  kind: n
# 3nd level sub classes:  C23C  kind: u
# 3nd level sub classes:  C23D  kind: u
# 3nd level sub classes:  C23F  kind: u
# 3nd level sub classes:  C23G  kind: u
# 2nd level classes:  C25  kind: c
# 3nd level sub classes:  C25  kind: n
# 3nd level sub classes:  C25  kind: i
# 3nd level sub classes:  C25B  kind: u
# 3nd level sub classes:  C25C  kind: u
# 3nd level sub classes:  C25D  kind: u
# 3nd level sub classes:  C25F  kind: u
# 2nd level classes:  C30  kind: c
# 3nd level sub classes:  C30B  kind: u
# 2nd level classes:  C40  kind: t
# 2nd level classes:  C40  kind: c
# 3nd level sub classes:  C40B  kind: u
# 2nd level classes:  C99  kind: c
# 3nd level sub classes:  C99Z  kind: u
# 1st level sections:  D  kind: s
# 2nd level classes:  D  kind: n
# 2nd level classes:  D01  kind: t
# 2nd level classes:  D01  kind: c
# 3nd level sub classes:  D01  kind: n
# 3nd level sub classes:  D01B  kind: u
# 3nd level sub classes:  D01C  kind: u
# 3nd level sub classes:  D01D  kind: u
# 3nd level sub classes:  D01F  kind: u
# 3nd level sub classes:  D01G  kind: u
# 3nd level sub classes:  D01H  kind: u
# 2nd level classes:  D02  kind: c
# 3nd level sub classes:  D02  kind: n
# 3nd level sub classes:  D02G  kind: u
# 3nd level sub classes:  D02H  kind: u
# 3nd level sub classes:  D02J  kind: u
# 2nd level classes:  D03  kind: c
# 3nd level sub classes:  D03C  kind: u
# 3nd level sub classes:  D03D  kind: u
# 3nd level sub classes:  D03J  kind: u
# 2nd level classes:  D04  kind: c
# 3nd level sub classes:  D04B  kind: u
# 3nd level sub classes:  D04C  kind: u
# 3nd level sub classes:  D04D  kind: u
# 3nd level sub classes:  D04G  kind: u
# 3nd level sub classes:  D04H  kind: u
# 2nd level classes:  D05  kind: c
# 3nd level sub classes:  D05B  kind: u
# 3nd level sub classes:  D05C  kind: u
# 2nd level classes:  D06  kind: c
# 3nd level sub classes:  D06B  kind: u
# 3nd level sub classes:  D06C  kind: u
# 3nd level sub classes:  D06F  kind: u
# 3nd level sub classes:  D06G  kind: u
# 3nd level sub classes:  D06H  kind: u
# 3nd level sub classes:  D06J  kind: u
# 3nd level sub classes:  D06L  kind: u
# 3nd level sub classes:  D06M  kind: u
# 3nd level sub classes:  D06N  kind: u
# 3nd level sub classes:  D06P  kind: u
# 3nd level sub classes:  D06Q  kind: u
# 2nd level classes:  D07  kind: c
# 3nd level sub classes:  D07B  kind: u
# 2nd level classes:  D21  kind: t
# 2nd level classes:  D21  kind: c
# 3nd level sub classes:  D21B  kind: u
# 3nd level sub classes:  D21C  kind: u
# 3nd level sub classes:  D21D  kind: u
# 3nd level sub classes:  D21F  kind: u
# 3nd level sub classes:  D21G  kind: u
# 3nd level sub classes:  D21H  kind: u
# 3nd level sub classes:  D21J  kind: u
# 2nd level classes:  D99  kind: c
# 3nd level sub classes:  D99Z  kind: u
# 1st level sections:  E  kind: s
# 2nd level classes:  E01  kind: t
# 2nd level classes:  E01  kind: c
# 3nd level sub classes:  E01B  kind: u
# 3nd level sub classes:  E01C  kind: u
# 3nd level sub classes:  E01D  kind: u
# 3nd level sub classes:  E01F  kind: u
# 3nd level sub classes:  E01H  kind: u
# 2nd level classes:  E02  kind: c
# 3nd level sub classes:  E02B  kind: u
# 3nd level sub classes:  E02C  kind: u
# 3nd level sub classes:  E02D  kind: u
# 3nd level sub classes:  E02F  kind: u
# 2nd level classes:  E03  kind: c
# 3nd level sub classes:  E03B  kind: u
# 3nd level sub classes:  E03C  kind: u
# 3nd level sub classes:  E03D  kind: u
# 3nd level sub classes:  E03F  kind: u
# 2nd level classes:  E04  kind: c
# 3nd level sub classes:  E04B  kind: u
# 3nd level sub classes:  E04C  kind: u
# 3nd level sub classes:  E04D  kind: u
# 3nd level sub classes:  E04F  kind: u
# 3nd level sub classes:  E04G  kind: u
# 3nd level sub classes:  E04H  kind: u
# 2nd level classes:  E05  kind: c
# 3nd level sub classes:  E05  kind: n
# 3nd level sub classes:  E05B  kind: u
# 3nd level sub classes:  E05C  kind: u
# 3nd level sub classes:  E05D  kind: u
# 3nd level sub classes:  E05F  kind: u
# 3nd level sub classes:  E05G  kind: u
# 2nd level classes:  E06  kind: c
# 3nd level sub classes:  E06B  kind: u
# 3nd level sub classes:  E06C  kind: u
# 2nd level classes:  E21  kind: t
# 2nd level classes:  E21  kind: c
# 3nd level sub classes:  E21  kind: n
# 3nd level sub classes:  E21B  kind: u
# 3nd level sub classes:  E21C  kind: u
# 3nd level sub classes:  E21D  kind: u
# 3nd level sub classes:  E21F  kind: u
# 2nd level classes:  E99  kind: c
# 3nd level sub classes:  E99Z  kind: u
# 1st level sections:  F  kind: s
# 2nd level classes:  F01  kind: t
# 2nd level classes:  F01  kind: n
# 2nd level classes:  F01  kind: i
# 2nd level classes:  F01  kind: c
# 3nd level sub classes:  F01B  kind: u
# 3nd level sub classes:  F01C  kind: u
# 3nd level sub classes:  F01D  kind: u
# 3nd level sub classes:  F01K  kind: u
# 3nd level sub classes:  F01L  kind: u
# 3nd level sub classes:  F01M  kind: u
# 3nd level sub classes:  F01N  kind: u
# 3nd level sub classes:  F01P  kind: u
# 2nd level classes:  F02  kind: c
# 3nd level sub classes:  F02B  kind: u
# 3nd level sub classes:  F02C  kind: u
# 3nd level sub classes:  F02D  kind: u
# 3nd level sub classes:  F02F  kind: u
# 3nd level sub classes:  F02G  kind: u
# 3nd level sub classes:  F02K  kind: u
# 3nd level sub classes:  F02M  kind: u
# 3nd level sub classes:  F02N  kind: u
# 3nd level sub classes:  F02P  kind: u
# 2nd level classes:  F03  kind: c
# 3nd level sub classes:  F03B  kind: u
# 3nd level sub classes:  F03C  kind: u
# 3nd level sub classes:  F03D  kind: u
# 3nd level sub classes:  F03G  kind: u
# 3nd level sub classes:  F03H  kind: u
# 2nd level classes:  F04  kind: c
# 3nd level sub classes:  F04  kind: n
# 3nd level sub classes:  F04B  kind: u
# 3nd level sub classes:  F04C  kind: u
# 3nd level sub classes:  F04D  kind: u
# 3nd level sub classes:  F04F  kind: u
# 2nd level classes:  F15  kind: t
# 2nd level classes:  F15  kind: c
# 3nd level sub classes:  F15B  kind: u
# 3nd level sub classes:  F15C  kind: u
# 3nd level sub classes:  F15D  kind: u
# 2nd level classes:  F16  kind: c
# 3nd level sub classes:  F16B  kind: u
# 3nd level sub classes:  F16C  kind: u
# 3nd level sub classes:  F16D  kind: u
# 3nd level sub classes:  F16F  kind: u
# 3nd level sub classes:  F16G  kind: u
# 3nd level sub classes:  F16H  kind: u
# 3nd level sub classes:  F16J  kind: u
# 3nd level sub classes:  F16K  kind: u
# 3nd level sub classes:  F16L  kind: u
# 3nd level sub classes:  F16M  kind: u
# 3nd level sub classes:  F16N  kind: u
# 3nd level sub classes:  F16P  kind: u
# 3nd level sub classes:  F16S  kind: u
# 3nd level sub classes:  F16T  kind: u
# 2nd level classes:  F17  kind: c
# 3nd level sub classes:  F17B  kind: u
# 3nd level sub classes:  F17C  kind: u
# 3nd level sub classes:  F17D  kind: u
# 2nd level classes:  F21  kind: t
# 2nd level classes:  F21  kind: c
# 3nd level sub classes:  F21  kind: n
# 3nd level sub classes:  F21H  kind: u
# 3nd level sub classes:  F21K  kind: u
# 3nd level sub classes:  F21L  kind: u
# 3nd level sub classes:  F21S  kind: u
# 3nd level sub classes:  F21V  kind: u
# 3nd level sub classes:  F21W  kind: u
# 3nd level sub classes:  F21Y  kind: u
# 2nd level classes:  F22  kind: c
# 3nd level sub classes:  F22  kind: n
# 3nd level sub classes:  F22B  kind: u
# 3nd level sub classes:  F22D  kind: u
# 3nd level sub classes:  F22G  kind: u
# 2nd level classes:  F23  kind: c
# 3nd level sub classes:  F23  kind: n
# 3nd level sub classes:  F23B  kind: u
# 3nd level sub classes:  F23C  kind: u
# 3nd level sub classes:  F23D  kind: u
# 3nd level sub classes:  F23G  kind: u
# 3nd level sub classes:  F23H  kind: u
# 3nd level sub classes:  F23J  kind: u
# 3nd level sub classes:  F23K  kind: u
# 3nd level sub classes:  F23L  kind: u
# 3nd level sub classes:  F23M  kind: u
# 3nd level sub classes:  F23N  kind: u
# 3nd level sub classes:  F23Q  kind: u
# 3nd level sub classes:  F23R  kind: u
# 2nd level classes:  F24  kind: c
# 3nd level sub classes:  F24  kind: n
# 3nd level sub classes:  F24B  kind: u
# 3nd level sub classes:  F24C  kind: u
# 3nd level sub classes:  F24D  kind: u
# 3nd level sub classes:  F24F  kind: u
# 3nd level sub classes:  F24H  kind: u
# 3nd level sub classes:  F24S  kind: u
# 3nd level sub classes:  F24T  kind: u
# 3nd level sub classes:  F24V  kind: u
# 2nd level classes:  F25  kind: c
# 3nd level sub classes:  F25B  kind: u
# 3nd level sub classes:  F25C  kind: u
# 3nd level sub classes:  F25D  kind: u
# 3nd level sub classes:  F25J  kind: u
# 2nd level classes:  F26  kind: c
# 3nd level sub classes:  F26B  kind: u
# 2nd level classes:  F27  kind: c
# 3nd level sub classes:  F27  kind: n
# 3nd level sub classes:  F27B  kind: u
# 3nd level sub classes:  F27D  kind: u
# 2nd level classes:  F28  kind: c
# 3nd level sub classes:  F28  kind: n
# 3nd level sub classes:  F28B  kind: u
# 3nd level sub classes:  F28C  kind: u
# 3nd level sub classes:  F28D  kind: u
# 3nd level sub classes:  F28F  kind: u
# 3nd level sub classes:  F28G  kind: u
# 2nd level classes:  F41  kind: t
# 2nd level classes:  F41  kind: c
# 3nd level sub classes:  F41  kind: n
# 3nd level sub classes:  F41A  kind: u
# 3nd level sub classes:  F41B  kind: u
# 3nd level sub classes:  F41C  kind: u
# 3nd level sub classes:  F41F  kind: u
# 3nd level sub classes:  F41G  kind: u
# 3nd level sub classes:  F41H  kind: u
# 3nd level sub classes:  F41J  kind: u
# 2nd level classes:  F42  kind: c
# 3nd level sub classes:  F42  kind: n
# 3nd level sub classes:  F42B  kind: u
# 3nd level sub classes:  F42C  kind: u
# 3nd level sub classes:  F42D  kind: u
# 2nd level classes:  F99  kind: c
# 3nd level sub classes:  F99Z  kind: u
# 1st level sections:  G  kind: s
# 2nd level classes:  G  kind: n
# 2nd level classes:  G01  kind: c
# 3nd level sub classes:  G01  kind: n
# 3nd level sub classes:  G01B  kind: u
# 3nd level sub classes:  G01C  kind: u
# 3nd level sub classes:  G01D  kind: u
# 3nd level sub classes:  G01F  kind: u
# 3nd level sub classes:  G01G  kind: u
# 3nd level sub classes:  G01H  kind: u
# 3nd level sub classes:  G01J  kind: u
# 3nd level sub classes:  G01K  kind: u
# 3nd level sub classes:  G01L  kind: u
# 3nd level sub classes:  G01M  kind: u
# 3nd level sub classes:  G01N  kind: u
# 3nd level sub classes:  G01P  kind: u
# 3nd level sub classes:  G01Q  kind: u
# 3nd level sub classes:  G01R  kind: u
# 3nd level sub classes:  G01S  kind: u
# 3nd level sub classes:  G01T  kind: u
# 3nd level sub classes:  G01V  kind: u
# 3nd level sub classes:  G01W  kind: u
# 2nd level classes:  G02  kind: c
# 3nd level sub classes:  G02  kind: n
# 3nd level sub classes:  G02B  kind: u
# 3nd level sub classes:  G02C  kind: u
# 3nd level sub classes:  G02F  kind: u
# 2nd level classes:  G03  kind: c
# 3nd level sub classes:  G03  kind: n
# 3nd level sub classes:  G03B  kind: u
# 3nd level sub classes:  G03C  kind: u
# 3nd level sub classes:  G03D  kind: u
# 3nd level sub classes:  G03F  kind: u
# 3nd level sub classes:  G03G  kind: u
# 3nd level sub classes:  G03H  kind: u
# 2nd level classes:  G04  kind: c
# 3nd level sub classes:  G04B  kind: u
# 3nd level sub classes:  G04C  kind: u
# 3nd level sub classes:  G04D  kind: u
# 3nd level sub classes:  G04F  kind: u
# 3nd level sub classes:  G04G  kind: u
# 3nd level sub classes:  G04R  kind: u
# 2nd level classes:  G05  kind: c
# 3nd level sub classes:  G05  kind: n
# 3nd level sub classes:  G05B  kind: u
# 3nd level sub classes:  G05D  kind: u
# 3nd level sub classes:  G05F  kind: u
# 3nd level sub classes:  G05G  kind: u
# 2nd level classes:  G06  kind: c
# 3nd level sub classes:  G06  kind: n
# 3nd level sub classes:  G06C  kind: u
# 3nd level sub classes:  G06D  kind: u
# 3nd level sub classes:  G06E  kind: u
# 3nd level sub classes:  G06F  kind: u
# 3nd level sub classes:  G06G  kind: u
# 3nd level sub classes:  G06J  kind: u
# 3nd level sub classes:  G06K  kind: u
# 3nd level sub classes:  G06M  kind: u
# 3nd level sub classes:  G06N  kind: u
# 3nd level sub classes:  G06Q  kind: u
# 3nd level sub classes:  G06T  kind: u
# 2nd level classes:  G07  kind: c
# 3nd level sub classes:  G07B  kind: u
# 3nd level sub classes:  G07C  kind: u
# 3nd level sub classes:  G07D  kind: u
# 3nd level sub classes:  G07F  kind: u
# 3nd level sub classes:  G07G  kind: u
# 2nd level classes:  G08  kind: c
# 3nd level sub classes:  G08B  kind: u
# 3nd level sub classes:  G08C  kind: u
# 3nd level sub classes:  G08G  kind: u
# 2nd level classes:  G09  kind: c
# 3nd level sub classes:  G09B  kind: u
# 3nd level sub classes:  G09C  kind: u
# 3nd level sub classes:  G09D  kind: u
# 3nd level sub classes:  G09F  kind: u
# 3nd level sub classes:  G09G  kind: u
# 2nd level classes:  G10  kind: c
# 3nd level sub classes:  G10  kind: n
# 3nd level sub classes:  G10  kind: i
# 3nd level sub classes:  G10B  kind: u
# 3nd level sub classes:  G10C  kind: u
# 3nd level sub classes:  G10D  kind: u
# 3nd level sub classes:  G10F  kind: u
# 3nd level sub classes:  G10G  kind: u
# 3nd level sub classes:  G10H  kind: u
# 3nd level sub classes:  G10K  kind: u
# 3nd level sub classes:  G10L  kind: u
# 2nd level classes:  G11  kind: c
# 3nd level sub classes:  G11B  kind: u
# 3nd level sub classes:  G11C  kind: u
# 2nd level classes:  G12  kind: c
# 3nd level sub classes:  G12B  kind: u
# 2nd level classes:  G16  kind: c
# 3nd level sub classes:  G16  kind: n
# 3nd level sub classes:  G16B  kind: u
# 3nd level sub classes:  G16C  kind: u
# 3nd level sub classes:  G16H  kind: u
# 3nd level sub classes:  G16Y  kind: u
# 3nd level sub classes:  G16Z  kind: u
# 2nd level classes:  G21  kind: c
# 3nd level sub classes:  G21B  kind: u
# 3nd level sub classes:  G21C  kind: u
# 3nd level sub classes:  G21D  kind: u
# 3nd level sub classes:  G21F  kind: u
# 3nd level sub classes:  G21G  kind: u
# 3nd level sub classes:  G21H  kind: u
# 3nd level sub classes:  G21J  kind: u
# 3nd level sub classes:  G21K  kind: u
# 2nd level classes:  G99  kind: c
# 3nd level sub classes:  G99Z  kind: u
# 1st level sections:  H  kind: s
# 2nd level classes:  H  kind: n
# 2nd level classes:  H01  kind: c
# 3nd level sub classes:  H01  kind: n
# 3nd level sub classes:  H01B  kind: u
# 3nd level sub classes:  H01C  kind: u
# 3nd level sub classes:  H01F  kind: u
# 3nd level sub classes:  H01G  kind: u
# 3nd level sub classes:  H01H  kind: u
# 3nd level sub classes:  H01J  kind: u
# 3nd level sub classes:  H01K  kind: u
# 3nd level sub classes:  H01L  kind: u
# 3nd level sub classes:  H01M  kind: u
# 3nd level sub classes:  H01P  kind: u
# 3nd level sub classes:  H01Q  kind: u
# 3nd level sub classes:  H01R  kind: u
# 3nd level sub classes:  H01S  kind: u
# 3nd level sub classes:  H01T  kind: u
# 2nd level classes:  H02  kind: c
# 3nd level sub classes:  H02B  kind: u
# 3nd level sub classes:  H02G  kind: u
# 3nd level sub classes:  H02H  kind: u
# 3nd level sub classes:  H02J  kind: u
# 3nd level sub classes:  H02K  kind: u
# 3nd level sub classes:  H02M  kind: u
# 3nd level sub classes:  H02N  kind: u
# 3nd level sub classes:  H02P  kind: u
# 3nd level sub classes:  H02S  kind: u
# 2nd level classes:  H03  kind: c
# 3nd level sub classes:  H03B  kind: u
# 3nd level sub classes:  H03C  kind: u
# 3nd level sub classes:  H03D  kind: u
# 3nd level sub classes:  H03F  kind: u
# 3nd level sub classes:  H03G  kind: u
# 3nd level sub classes:  H03H  kind: u
# 3nd level sub classes:  H03J  kind: u
# 3nd level sub classes:  H03K  kind: u
# 3nd level sub classes:  H03L  kind: u
# 3nd level sub classes:  H03M  kind: u
# 2nd level classes:  H04  kind: c
# 3nd level sub classes:  H04  kind: n
# 3nd level sub classes:  H04B  kind: u
# 3nd level sub classes:  H04H  kind: u
# 3nd level sub classes:  H04J  kind: u
# 3nd level sub classes:  H04K  kind: u
# 3nd level sub classes:  H04L  kind: u
# 3nd level sub classes:  H04M  kind: u
# 3nd level sub classes:  H04N  kind: u
# 3nd level sub classes:  H04Q  kind: u
# 3nd level sub classes:  H04R  kind: u
# 3nd level sub classes:  H04S  kind: u
# 3nd level sub classes:  H04W  kind: u
# 2nd level classes:  H05  kind: c
# 3nd level sub classes:  H05B  kind: u
# 3nd level sub classes:  H05C  kind: u
# 3nd level sub classes:  H05F  kind: u
# 3nd level sub classes:  H05G  kind: u
# 3nd level sub classes:  H05H  kind: u
# 3nd level sub classes:  H05K  kind: u
# 2nd level classes:  H99  kind: c
# 3nd level sub classes:  H99Z  kind: u

# %% [markdown]
# now we learn python and find others ways, to iterate over all children, checking with if for specific 'kind' of entries.

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

ipcEntry = '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'
count = 0
start = time.time()

whatlevel = "1"

for element in root.iter(ipcEntry):
  if element.attrib['kind'] == whatlevel:
    count = count + 1
    #print(count, element.attrib['symbol'])

print("for kind", element, "found", count, 'entries in:', time.time() - start, 'sec')
# Out:
# for kind <Element {http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry at 0x7f68db963690> found 23390 entries in: 0.06341743469238281 sec

# %% [markdown]
# Now with a tuple of all the "kind" of entries i want to check...

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

ipcEntry = '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'
count = 0

whatlevel = ("s","c","u","m","1","2","3","4","5","6","7","8","9","A","B")

for level in whatlevel:

  tic = time.perf_counter() * 1000

  for element in root.iter(ipcEntry):
    if element.attrib['kind'] == level:
      count = count + 1
      #print(count, element.attrib['symbol'])

  toc = time.perf_counter() * 1000

  print("for kind", level, "found ", count, f"entries in: {(toc - tic):0.0f} ms")

  count = 0
# Out:
# for kind s found  8 entries in: 146 ms
# for kind c found  131 entries in: 58 ms
# for kind u found  646 entries in: 61 ms
# for kind m found  7523 entries in: 66 ms
# for kind 1 found  23390 entries in: 66 ms
# for kind 2 found  23048 entries in: 61 ms
# for kind 3 found  13661 entries in: 60 ms
# for kind 4 found  5934 entries in: 62 ms
# for kind 5 found  1987 entries in: 61 ms
# for kind 6 found  638 entries in: 62 ms
# for kind 7 found  155 entries in: 60 ms
# for kind 8 found  68 entries in: 59 ms
# for kind 9 found  10 entries in: 59 ms
# for kind A found  4 entries in: 68 ms
# for kind B found  4 entries in: 57 ms

# %% [markdown]
# now with a dictonary

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

ipcEntry = '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'

whatlevel = {
  's':'section',
  't':'sub-section title',
  'c':'class',
  'I':'sub-class index',
  'u':'sub-class',
  'g':'guidance heading',
  'm':'main group',
  '1':'.subgroup',
  '2':'..subgroup',
  '3':'...subgroup',
  '4':'....subgroup',
  '5':'.....subgroup',
  '6':'......subgroup',
  '7':'.......subgroup',
  '8':'........subgroup',
  '9':'.........subgroup',
  'A':'..........subgroup',
  'B':'...........subgroup',
  'n':'note'}

for level in whatlevel.keys():

  count = 0
  start = time.time()

  for element in root.iter(ipcEntry):
    if element.attrib['kind'] == level:
      count = count + 1
      #print(count, element.attrib['symbol'])
  print("for kind ", whatlevel[level], "found ", count, f'entries (in: {(time.time() - start) * 1000:0.0f} ms)')

  count = 0
  start = time.time()
# Out:
# for kind  section found  8 entries (in: 148 ms)
# for kind  sub-section title found  20 entries (in: 62 ms)
# for kind  class found  131 entries (in: 66 ms)
# for kind  sub-class index found  0 entries (in: 63 ms)
# for kind  sub-class found  646 entries (in: 66 ms)
# for kind  guidance heading found  547 entries (in: 63 ms)
# for kind  main group found  7523 entries (in: 64 ms)
# for kind  .subgroup found  23390 entries (in: 63 ms)
# for kind  ..subgroup found  23048 entries (in: 68 ms)
# for kind  ...subgroup found  13661 entries (in: 62 ms)
# for kind  ....subgroup found  5934 entries (in: 60 ms)
# for kind  .....subgroup found  1987 entries (in: 65 ms)
# for kind  ......subgroup found  638 entries (in: 66 ms)
# for kind  .......subgroup found  155 entries (in: 61 ms)
# for kind  ........subgroup found  68 entries (in: 60 ms)
# for kind  .........subgroup found  10 entries (in: 60 ms)
# for kind  ..........subgroup found  4 entries (in: 73 ms)
# for kind  ...........subgroup found  4 entries (in: 66 ms)
# for kind  note found  959 entries (in: 72 ms)

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

ipcEntry = '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'

whatLevel = ["s","c","u","m","1","2","3","4","5","6","7","8","9","A","B"]

tic = time.perf_counter() * 1000
def iterDurchsXML(level):
  count = 0
  for element in root.iter(ipcEntry):
    if element.attrib['kind'] == level:
      count = count + 1
      #print(count, element.attrib['symbol'])

  print("for kind", level, "found ", count)

for level in whatLevel:
  iterDurchsXML(level)

toc = time.perf_counter() * 1000

print("time needed:", f"entries in: {(toc - tic):0.0f} ms")
# Out:
# for kind s found  8
# for kind c found  131
# for kind u found  646
# for kind m found  7523
# for kind 1 found  23390
# for kind 2 found  23048
# for kind 3 found  13661
# for kind 4 found  5934
# for kind 5 found  1987
# for kind 6 found  638
# for kind 7 found  155
# for kind 8 found  68
# for kind 9 found  10
# for kind A found  4
# for kind B found  4
# time needed: entries in: 578 ms

# %% [markdown]
# #Sample with a recursive function
#
# Instead of iter through the whole, we recursively go through the children of each entry. much more fun!

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

whatLevel = ["s","c","u","m","1","2","3","4","5","6","7","8","9","A","B"]

### here is my recursive function

tic = time.perf_counter() * 1000
list = [0,0,0]

def recWalker(node, list, kind):
  for child in node:
    list[0] += 1
    if not child.attrib == {}:
      list[1] += 1
      attrib = child.attrib['kind']
      if attrib == kind:
        list[2] += 1
        print("kind", attrib, list)
      #here I call the function within the function! thats makes it recursive!
      recWalker(child, list, kind)

# this ist the first call of the function
# argument is the xml, a empty list and the "kind" of entries, i want to find.
recWalker(root, list, "A")

toc = time.perf_counter() * 1000

print(f'time needed: {(toc - tic):0.0f} ms')
# Out:
# kind A [144005, 72003, 1]
# kind A [144015, 72008, 2]
# kind A [144023, 72012, 3]
# kind A [144045, 72023, 4]
# time needed: 172 ms

# %% [markdown]
# #Next Idea: minidom
#
# Use a different module, here xml.dom.minidom
#
# * as described [here](https://docs.python.org/3/library/xml.dom.minidom.html#module-xml.dom.minidom) at python.org
# * and the DOM [here]((https://www.w3.org/TR/REC-DOM-Level-1/level-one-core.html)) at w3c.org
#
# Interesting functions would access Node with parentNode, childNodes, firstChild, lastChild, previousSibling and nextSibling and their content and attributes.
#
# loading very slow! but after loading access to the entries are fast.

# %%
import xml.dom.minidom
#the module used for parsing the xml file is imported

xml_file = './EN_ipc_scheme_20210101.xml'
tag_name = 'ipcEntry'
attr_name = 'symbol'

#This function is declared with three arguements namely the xml file to be parsed, the tag name and the attribute name and it does the magic
def generic_dom(xml_file,tag_name,attr_name):
  doc = xml.dom.minidom.parse(xml_file)
  tags = doc.getElementsByTagName(tag_name)
  for any_attr in tags:
    attr = any_attr.getAttribute(attr_name)
    print(attr)

generic_dom(xml_file,tag_name,attr_name)

# %% [markdown]
# # Next Sample with recursive function and a XPath Call

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

whatLevel = ["s","c","u","m","1","2","3","4","5","6","7","8","9","A","B"]

### here is my recursive function

tic = time.perf_counter() * 1000
list = [0,0,0]

def recWalker(node, list, kind):
  for child in node:
    list[0] += 1
    if not child.attrib == {}:
      list[1] += 1
      attrib = child.attrib['kind']
      if attrib == kind:
        list[2] += 1
        alltext = child.xpath('descendant-or-self::text()')
        print("kind", attrib, list)
        print(alltext[0])
      #here I call the function within the function! thats makes it recursive!
      recWalker(child, list, kind)

# this ist the first call of the function
# argument is the xml, a empty list and the "kind" of entries, i want to find.
recWalker(root, list, "9")

toc = time.perf_counter() * 1000

print(f'time needed: {(toc - tic):0.0f} ms')
# Out:
# kind 9 [135193, 67597, 1]
# the data current flowing through the driving transistor during a setting phase, e.g. by using a switch for connecting the driving transistor to the data driver
# kind 9 [143757, 71879, 2]
# Dynamic random access memory structures (DRAM)
# kind 9 [143759, 71880, 3]
# Static random access memory structures (SRAM)
# kind 9 [143761, 71881, 4]
# Read-only memory structures (ROM)
# kind 9 [143997, 71999, 5]
# with cell select transistors, e.g. NAND
# kind 9 [144001, 72001, 6]
# of memory regions comprising cell select transistors, e.g. NAND
# kind 9 [144003, 72002, 7]
# Simultaneous manufacturing of periphery and memory cells
# kind 9 [144021, 72011, 8]
# with source and drain on different levels, e.g. with sloping channels
# kind 9 [144035, 72018, 9]
# with cell select transistors, e.g. NAND
# kind 9 [144043, 72022, 10]
# with source and drain on different levels, e.g. with sloping channels
# time needed: 292 ms

# %% [markdown]
# # Dictionary Approach
# So, letz see, if I can reate a dictionary with almost all the content of the IPC XML.
#
# letz have a look at one entry
#
# now start thinking, how to extract the values in a nice way
#
# * each ipcEntry has attributes
#   * each ipcEntry has kind = 1...16
#   * each ipcEntry has its symbol
#   * each ipcEntry has a type
#
# * each ipcEntry has one parent and one to many children
#   * each ipcEntry has one parent ipcEntry, except for the first, upper 8 ipcEntries (remember its a hierarchical tree).
#   * each ipcEntry has one or many child ipcEntries
#
#
# * each ipcEntry has a textBody
#   * each textBody has a title
#     * each title has one or many titlePart
#       * each titlePart has one text
#       * each titlePart has one or many entryReference with a sref to another symbol
#
# here an example
# ```
# <ipcEntry kind="u" symbol="A01B" entryType="K">
#   <textBody>
#     <title>
#       <titlePart>
#          <text>SOIL WORKING IN AGRICULTURE OR FORESTRY</text>
#       </titlePart>
#       <titlePart>
#         <text>PARTS, DETAILS, OR ACCESSORIES OF AGRICULTURAL MACHINES OR IMPLEMENTS, IN GENERAL</text>
#            <entryReference>making or covering furrows or holes for sowing, planting or manuring <sref ref="A01C0005000000"/>
#            </entryReference>
#            <entryReference>machines for harvesting root crops <sref ref="A01D"/>
#            </entryReference>
#            <entryReference>mowers convertible to soil working apparatus or capable of soil working <sref ref="A01D0042040000"/>
#            </entryReference>
#            <entryReference>mowers combined with soil working implements <sref ref="A01D0043120000"/>
#            </entryReference>
#            <entryReference>soil working for engineering purposes <sref ref="E01"/>,<sref ref="E02"/>,<sref ref="E21"/>
#            </entryReference>
#         </titlePart>
#       </title>
#     </textBody>
# ```

# %%
from lxml import etree as ET
import time

filename = "./EN_ipc_scheme_20210101.xml"

parser = ET.XMLParser(remove_blank_text=True)
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

ipcEntry = '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'
ipcXML = {}

tic = time.perf_counter() * 1000
count = 0

for element in root.iter(ipcEntry):
  if not element.attrib == {}:
    count = count + 1

    elementAttribKind   = element.attrib['kind']
    elementAttribSymbol = element.attrib['symbol']

    elementAttribType   = element.attrib['entryType']

    elementText = element.xpath('descendant-or-self::text()')
    elementText = elementText[0]
    if count < 100:
      print(count, elementAttribKind, elementAttribType, elementAttribSymbol, elementText)

toc = time.perf_counter() * 1000

print("time needed:", f"entries in: {(toc - tic):0.0f} ms")

# %%
from lxml import etree as ET
import time

# File path to the IPC XML
filename = "./EN_ipc_scheme_20210101.xml"

# Define the namespace and parser
ipc_namespace = '{http://www.wipo.int/classifications/ipc/masterfiles}'
ipcEntry = f"{ipc_namespace}ipcEntry"
text_body = f"{ipc_namespace}textBody"
title_part = f"{ipc_namespace}titlePart"
text = f"{ipc_namespace}text"
parser = ET.XMLParser(remove_blank_text=True)

# Parse the XML file
tree = ET.parse(filename, parser=parser)
root = tree.getroot()

# Initialize dictionary for sub-class mapping
sub_class_mapping = {}

# Start measuring time
start = time.time()

# Iterate through the XML to extract sub-class information
for element in root.iter(ipcEntry):
    if element.attrib.get("kind") == "u":  # Focus on sub-classes
        symbol = element.attrib.get("symbol")  # Extract sub-class symbol

        # Locate the title text within the nested structure
        text_element = element.find(f".//{text_body}//{title_part}//{text}")
        title = text_element.text.strip() if text_element is not None else "No Title"

        sub_class_mapping[symbol] = title

# Print execution time
print(f"Extracted {len(sub_class_mapping)} sub-classes in {(time.time() - start) * 1000:.0f} ms.")

# Print a sample of the extracted data
for symbol, title in list(sub_class_mapping.items())[:5]:
    print(f"{symbol}: {title}")
# Out:
# Extracted 646 sub-classes in 151 ms.
# A01B: SOIL WORKING IN AGRICULTURE OR FORESTRY
# A01C: PLANTING
# A01D: HARVESTING
# A01F: THRESHING
# A01G: HORTICULTURE
